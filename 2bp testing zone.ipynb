# %%
import matplotlib.pyplot as plt
from two_body import *

# %%
y = Y0[:]
for i in range(STEPS):
    y = exp_euler_timestep(y)
position_arr = np.array(position_arr)

# %%
position_arr.shape
# Out:
# (1000, 2, 2)

# %%
m1,m2 = np.array(position_arr).T[0],np.array(position_arr).T[1]
# Out:
# (2, 1000)

# %%
plt.subplots(figsize=(10,10))
plt.plot(m1[0],m1[1],'x')
plt.plot(m2[0],m2[1])
